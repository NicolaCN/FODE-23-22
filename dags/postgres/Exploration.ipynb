# %%
# Function to create time dimensions DataFrame
def create_time_dimension(start_year, end_year):
    start_date = f"{start_year}-01-01"
    end_date = f"{end_year}-12-31"
    
    date_range = pd.date_range(start=start_date, end=end_date, freq='D')
    
    data = {
        'Date': date_range,
        'Week': date_range.isocalendar().week,
        'Month': date_range.month,
        'Trimester': (date_range.month - 1) // 3 + 1,
        'Semester': (date_range.month <= 6).astype(int) + 1,
        'Year': date_range.year
    }
    
    df = pd.DataFrame(data)
    return df

# Create time dimension DataFrame for the years 2019 to 2024
time_dimension_df = create_time_dimension(2019, 2024)

# Display the DataFrame
print(time_dimension_df.head())

# %%
# Countries and iso_codes compatibility
import pandas as pd
df_vaccinations = pd.read_csv('vaccinations.csv')
df_cases_deaths = pd.read_csv('cases_deaths_wrangled.csv')
df_government_measures = pd.read_csv('government_measures.csv')
df_vaccinations = df_vaccinations[['location', 'iso_code']]
df_cases_deaths = df_cases_deaths[['Country', 'Country_code']]
df_government_measures = df_government_measures[['CountryName', 'CountryCode']]

# %%
conv = pd.read_csv('location.csv')
conv = conv[['alpha-2', 'alpha-3']]

# %%
def convert2to3(x):
    merged = pd.merge(x, conv, how='left', left_on=[x.columns[1]], right_on=['alpha-2'])
    return set(merged['alpha-3'])
def convert3to2(x):
    merged = pd.merge(x, conv, how='left', left_on=[x.columns[1]], right_on=['alpha-3'])
    return set(merged['alpha-2'])

vacc = set(df_vaccinations["iso_code"])
cd = set(df_cases_deaths["Country_code"])
gov = set(df_government_measures["CountryCode"])
print(convert3to2(df_vaccinations).__len__(), vacc.__len__())
print(convert2to3(df_cases_deaths).__len__(), cd.__len__())
print(convert3to2(df_government_measures).__len__(), gov.__len__())

print(vacc.__len__(), cd.__len__(), gov.__len__())
# Out:
# 217 235
# 233 237
# 184 185
# 235 237 185
# {'ABW',
#  'AD',
#  'AE',
#  'AF',
#  'AFG',
#  'AGO',
#  'AL',
#  'ALB',
#  'AND',
#  'AO',
#  'AR',
#  'ARE',
#  'ARG',
#  'AT',
#  'AU',
#  'AUS',
#  'AUT',
#  'AW',
#  'AZ',
#  'AZE',
#  'BA',
#  'BB',
#  'BD',
#  'BDI',
#  'BE',
#  'BEL',
#  'BEN',
#  'BF',
#  'BFA',
#  'BG',
#  'BGD',
#  'BGR',
#  'BH',
#  'BHR',
#  'BHS',
#  'BI',
#  'BIH',
#  'BJ',
#  'BLR',
#  'BLZ',
#  'BM',
#  'BMU',
#  'BN',
#  'BO',
#  'BOL',
#  'BR',
#  'BRA',
#  'BRB',
#  'BRN',
#  'BS',
#  'BT',
#  'BTN',
#  'BW',
#  'BWA',
#  'BY',
#  'BZ',
#  'CA',
#  'CAF',
#  'CAN',
#  'CD',
#  'CF',
#  'CG',
#  'CH',
#  'CHE',
#  'CHL',
#  'CHN',
#  'CI',
#  'CIV',
#  'CL',
#  'CM',
#  'CMR',
#  'CN',
#  'CO',
#  'COD',
#  'COG',
#  'COL',
#  'CPV',
#  'CR',
#  'CRI',
#  'CU',
#  'CUB',
#  'CV',
#  'CY',
#  'CYP',
#  'CZ',
#  'CZE',
#  'DE',
#  'DEU',
#  'DJ',
#  'DJI',
#  'DK',
#  'DM',
#  'DMA',
#  'DNK',
#  'DO',
#  'DOM',
#  'DZ',
#  'DZA',
#  'EC',
#  'ECU',
# ...
